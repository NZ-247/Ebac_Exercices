# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %% [markdown]
# ### resolução da atividade 1.1)

# %%
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'

# %%
rq = requests.get(url)

# %%
rq.status_code
# Out:
# 200

# %%
data_json = rq.json()
print(data_json['items'])
# Out:
# [{'id_pleito': 8215, 'tipo_interessado': 'Município', 'interessado': 'Guarujá', 'cod_ibge': 3518701, 'uf': 'SP', 'num_pvl': None, 'status': 'Arquivado por decurso de prazo', 'num_processo': '17944.000734/2014-45', 'data_protocolo': '2014-09-25T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'PAC 2 - Pró-Transporte - Pavimentação e Qualificação de Vias', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Caixa Econômica Federal', 'moeda': 'Real', 'valor': 6070996.57, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '13/02/2015'}, {'id_pleito': 8222, 'tipo_interessado': 'Município', 'interessado': 'Prata', 'cod_ibge': 2512200, 'uf': 'PB', 'num_pvl': None, 'status': 'Arquivado', 'num_processo': '17944.000736/2008-96', 'data_protocolo': '2008-05-19T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Caminho da Escola 2', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco do Brasil S/A', 'moeda': 'Real', 'valor': 240750, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '29/08/2008'}, {'id_pleito': 8233, 'tipo_interessado': 'Município', 'interessado': 'Lajes', 'cod_ibge': 2406700, 'uf': 'RN', 'num_pvl': None, 'status': 'Arquivado', 'num_processo': '17944.000738/2008-85', 'data_protocolo': '2008-06-17T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Caminho da Escola 2', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco do Brasil S/A', 'moeda': 'Real', 'valor': 350000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '15/09/2008'}, {'id_pleito': 9509, 'tipo_interessado': 'Município', 'interessado': 'Matão', 'cod_ibge': 3529302, 'uf': 'SP', 'num_pvl': None, 'status': 'Arquivado a pedido', 'num_processo': '17944.000996/2009-42', 'data_protocolo': '2014-07-25T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Provias 2009', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco do Brasil S/A', 'moeda': 'Real', 'valor': 2200000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '31/07/2014'}, {'id_pleito': 9511, 'tipo_interessado': 'Município', 'interessado': 'Palmeira', 'cod_ibge': 4117701, 'uf': 'PR', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '17944.000996/2011-67', 'data_protocolo': '2011-11-28T02:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'PAC 2 - Pró-Transporte - Pavimentação e Qualificação de Vias', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Caixa Econômica Federal', 'moeda': 'Real', 'valor': 7274150, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '27/12/2011'}, {'id_pleito': 9516, 'tipo_interessado': 'Município', 'interessado': 'Arceburgo', 'cod_ibge': 3104106, 'uf': 'MG', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '17944.000997/2010-21', 'data_protocolo': '2010-08-24T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco de Desenvolvimento de Minas Gerais S/A', 'moeda': 'Real', 'valor': 457461, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '26/08/2010'}, {'id_pleito': 9529, 'tipo_interessado': 'Município', 'interessado': 'Campanário', 'cod_ibge': 3110806, 'uf': 'MG', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '17944.000999/2010-10', 'data_protocolo': '2010-07-07T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco de Desenvolvimento de Minas Gerais S/A', 'moeda': 'Real', 'valor': 250000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '28/07/2010'}, {'id_pleito': 9534, 'tipo_interessado': 'Município', 'interessado': 'Varginha', 'cod_ibge': 3170701, 'uf': 'MG', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '17944.001000/2013-01', 'data_protocolo': '2013-09-02T03 ...

# %%
df = pd.DataFrame(data_json['items'])
df.head()
# Out:
#    id_pleito tipo_interessado interessado  cod_ibge  uf num_pvl  \
# 0       8215        Município     Guarujá   3518701  SP    None
# 1       8222        Município       Prata   2512200  PB    None
# 2       8233        Município       Lajes   2406700  RN    None
# 3       9509        Município       Matão   3529302  SP    None
# 4       9511        Município    Palmeira   4117701  PR    None
#
#                            status          num_processo        data_protocolo  \
# 0  Arquivado por decurso de prazo  17944.000734/2014-45  2014-09-25T03:00:00Z
# 1                       Arquivado  17944.000736/2008-96  2008-05-19T03:00:00Z
# 2                       Arquivado  17944.000738/2008-85  2008-06-17T03:00:00Z
# 3              Arquivado a pedido  17944.000996/2009-42  2014-07-25T03:00:00Z
# 4                        Deferido  17944.000996/2011-67  2011-11-28T02:00:00Z
#
#                  tipo_operacao  \
# 0  Operação contratual interna
# 1  Operação contratual interna
# 2  Operação contratual interna
# 3  Operação contratual interna
# 4  Operação contratual interna
#
#                                           finalidade  \
# 0  PAC 2 - Pró-Transporte - Pavimentação e Qualif...
# 1                                Caminho da Escola 2
# 2                                Caminho da Escola 2
# 3                                       Provias 2009
# 4  PAC 2 - Pró-Transporte - Pavimentação e Qualif...
#
#                        tipo_credor                   credor moeda       valor  \
# 0  Instituição Financeira Nacional  Caixa Econômica Federal  Real  6070996.57
# 1  Instituição Financeira Nacional      Banco do Brasil S/A  Real   240750.00
# 2  Instituição Financeira Nacional      Banco do Brasil S/A  Real   350000.00
# 3  Instituição Financeira Nacional      Banco do Brasil S/A  Real  2200000.00
# 4  Instituição Financeira Nacional  Caixa Econômica Federal  Real  7274150.00
#
#    pvl_assoc_divida  pvl_contradado_credor data_status
# 0                 0                      0  13/02/2015
# 1                 0                      0  29/08/2008
# 2                 0                      0  15/09/2008
# 3                 0                      0  31/07/2014
# 4                 1                      0  27/12/2011

# %%
df = df[df['uf'] == 'RJ']
df
# Out:
#       id_pleito tipo_interessado                  interessado  cod_ibge  uf  \
# 11         6676        Município                Volta Redonda   3306305  RJ
# 31         9161        Município                Volta Redonda   3306305  RJ
# 230        7129           Estado               Rio de Janeiro        33  RJ
# 232        7141           Estado               Rio de Janeiro        33  RJ
# 245        9075        Município               Barra do Piraí   3300308  RJ
# ...         ...              ...                          ...       ...  ..
# 4428      11697        Município              Duque de Caxias   3301702  RJ
# 4466       9452        Município               Rio de Janeiro   3304557  RJ
# 4538      13560           Estado               Rio de Janeiro        33  RJ
# 4571       8889        Município  Engenheiro Paulo de Frontin   3301801  RJ
# 4901       6388        Município                     Itaboraí   3301900  RJ
#
#      num_pvl                                             status  \
# 11      None                                          Arquivado
# 31      None                                 Arquivado a pedido
# 230     None  Encaminhado à PGFN com manifestação técnica fa...
# 232     None  Encaminhado à PGFN com manifestação técnica fa...
# 245     None                                          Arquivado
# ...      ...                                                ...
# 4428    None                                          Arquivado
# 4466    None                                          Arquivado
# 4538    None                                           Deferido
# 4571    None                                          Arquivado
# 4901    None                                       Regularizado
#
#               num_processo        data_protocolo  \
# 11    17944.000407/2008-45  2008-08-28T03:00:00Z
# 31    17944.000917/2010-37  2013-12-04T02:00:00Z
# 230   17944.000504/2014-86  2014-04-02T03:00:00Z
# 232   17944.000506/2014-75  2014-04-02T03:00:00Z
# 245   17944.000898/2008-24  2008-08-18T03:00:00Z
# ...                    ...                   ...
# 4428  17944.001505/2008-08  2008-07-31T03:00:00Z
# 4466  17944.000984/2009-18  2009-08-13T03:00:00Z
# 4538  19405.000026/2002-01  2002-06-25T03:00:00Z
# 4571  17944.000861/2008-04  2008-10-14T03:00:00Z
# 4901  17944.000334/2012-78  2018-11-22T02:00:00Z
#
#                                           tipo_operacao  \
# 11                          Operação contratual interna
# 31                          Operação contratual interna
# 230   Operação contratual interna (com garantia da U...
# 232   Operação contratual interna (com garantia da U...
# 245                         Operação contratual interna
# ...                                                 ...
# 4428                        Operação contratual interna
# 4466  Operação contratual externa (com garantia da U...
# 4538                        Operação contratual interna
# 4571                        Operação contratual interna
# 4901                        Operação contratual interna
#
#                                       finalidade  \
# 11                       PAC - Saneamento - 2008
# 31                      Aquisição de títulos CVS
# 230                               Infraestrutura
# 232                  Desenvolvimento sustentável
# 245                          Caminho da Escola 2
# ...                                          ...
# 4428                         Caminho da Escola 4
# 4466                              Multissetorial
# 4538                              Infraestrutura
# 4571                         Caminho da Escola 2
# 4901  Regularização de Dívida - Energia Elétrica
#
#                                tipo_credor  \
# 11         Instituição Financeira Nacional
# 31         Instituição Financeira Nacional
# 230        Instituição Financeira Nacional
# 232        Instituição Financeira Nacional
# 245        Instituição Financeira Nacional
# ...                                    ...
# 4428       Instituição Financeira Nacional
# 4466  Instituição Financeira Internacional
# 4538       Instituição Financeira Nacional
# 4571       Instituição Financeira Nacional
# 4901                   Empresa Não Estatal
#
#                                                  credor          moeda  \
# 11    Banco Nacional de Desenvolvimento Econômico e ...           Real
# 31                              Caixa Econômica Federal           Real
# 230                              Banco BTG Pactual S.A.           Real
# 232   Banco de Investimentos Credit Suisse (Brasil) ...           Real
# 245                                 Banco do Brasil S/A           Real
# ...                                                 ...            ...
# 4428                                Banco do Brasil S/A           Real
# 4466  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 4538  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 4571                                Banco do Brasil S/A           Real
# 4901                       Ampla Energia e Serviços S/A           Real
#
#              valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 11    5.530000e+07                 0                      0  07/11/2008
# 31    2.000000e+07                 0                      0  20/02/2014
# 230   4.500000e+08                 1                      0  01/09/2014
# 232   6.000000e+08                 1                      0  01/09/2014
# 245   4.594000e+05                 0                      0  30/10/2008
# ...            ...               ...                    ...         ...
# 4428  1.368000e+06                 0                      0  30/10/2008
# 4466  1.000000e-02                 0                      0  09/02/2010
# 4538  4.994200e+04                 1                      0  27/06/2002
# 4571  4.007000e+05                 0                      0  07/01/2009
# 4901  8.493818e+06                 0                      0  04/12/2018
#
# [80 rows x 18 columns]

# %% [markdown]
# ### resolução da atividade 1.2)

# %%
df['status'].value_counts()[:3]
# Out:
# status
# Deferido                                                 27
# Encaminhado à PGFN com manifestação técnica favorável    14
# Arquivado                                                10
# Name: count, dtype: int64

# %% [markdown]
# ### resolução da atividade 1.3)

# %%
df['data_status'] = df['data_status'].apply(str)
df['data_status']
# Out:
# 11      07/11/2008
# 31      20/02/2014
# 230     01/09/2014
# 232     01/09/2014
# 245     30/10/2008
#            ...
# 4428    30/10/2008
# 4466    09/02/2010
# 4538    27/06/2002
# 4571    07/01/2009
# 4901    04/12/2018
# Name: data_status, Length: 80, dtype: object

# %%
df['data_status'] = pd.to_datetime(df['data_status'], format='%d/%m/%y')

df['ano_status'] = df['data_status'].dt.year
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 df['data_status'] = pd.to_datetime(df['data_status'], format='%d/%m/%y')
#       3 df['ano_status'] = df['data_status'].dt.year
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1112, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1110         result = arg.map(cache_array)
#    1111     else:
# -> 1112         values = convert_listlike(arg._values, format)
#    1113         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1114 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:488, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     486 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     487 if format is not None and format != "mixed":
# --> 488     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     490 result, tz_parsed = objects_to_datetime64ns(
#     491     arg,
#     492     dayfirst=dayfirst,
#    (...)
#     496     allow_object=True,
#     497 )
#     499 if tz_parsed is not None:
#     500     # We can take a shortcut since the datetime64 numpy array
#     501     # is in UTC
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:519, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     508 def _array_strptime_with_fallback(
#     509     arg,
#     510     name,
#    (...)
#     514     errors: str,
#     515 ) -> Index:
#     516     """
#     517     Call array_strptime, with fallback behavior depending on 'errors'.
#     518     """
# --> 519     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     520     if any(tz is not None for tz in timezones):
#     521         return _return_parsed_timezone_results(result, timezones, utc, name)
#
# File strptime.pyx:534, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:359, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: unconverted data remains when parsing with format "%d/%m/%y": "08", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui

# %%
# 2) Seu código aqui

# %%
# 3) Seu código aqui

# %%
# 4) Seu código aqui
